# %%
import pandas as pd
import anthropic
import os
import sys
sys.path.append('..')
from config import ANTHROPIC_API_KEY 
import openpyxl
import requests
import io 
from io import BytesIO
import base64
import sys
from PIL import Image

# Initialize Claude client
if not ANTHROPIC_API_KEY:
    raise ValueError("Please set ANTHROPIC_API_KEY environment variable")
client = anthropic.Anthropic(api_key=ANTHROPIC_API_KEY)

# System prompt matching the larger script
SYSTEM_PROMPT = """You must reply with NO explanations, NO headers, NO extra text.
Language: ENGLISH. Keep the output strictly in the required format.

You will receive ONE medical question with:
- Text fields: QuestionID, Question, options A..E (some may be null).
- Optionally ONE image immediately after the text (when provided).

Task: choose EXACTLY ONE correct option among A, B, C, D, E for the QuestionID.
You may consider the image when present.

STRICT output format:
QuestionID, LETTER

Example:
ES3341, B

RULES:
- Output EXACTLY ONE line in the exact format above.
- Do NOT repeat the instructions.
- Do NOT include the option text, ONLY the letter."""

# New system prompt that asks for reasoning
SYSTEM_PROMPT_WITH_REASONING = """You will receive ONE medical question with:
- Text fields: QuestionID, Question, options A..E (some may be null).
- Optionally ONE image immediately after the text (when provided).

Task: 
1. Choose EXACTLY ONE correct option among A, B, C, D, E for the QuestionID.
2. Provide your reasoning for selecting this answer.

Output format:
QuestionID, LETTER
Reasoning: [Your detailed reasoning here]

Example:
ES3341, B
Reasoning: The image shows characteristic signs of..."""

USER_LEAD = "Below is a single record. Use ONLY the relevant information."

def build_content_like_main_script(question_id: str, question_text: str, options: dict) -> list:
    """Build content in the same format as the main script"""
    content = []
    
    # Start with the lead text
    lines = [USER_LEAD, f"QuestionID: {question_id}"]
    
    # Add question text
    if question_text:
        lines.append(f"Question: {question_text}")
    
    # Add options A through E
    for label in ["A", "B", "C", "D", "E"]:
        option_text = options.get(label, "")
        lines.append(f"{label}) {option_text if option_text else ''}")
    
    # Create text content block
    content.append({
        "type": "text",
        "text": "\n".join(lines)
    })
    
    return content

def call_claude_with_image(content, use_reasoning=False):
    """Call Claude API and return parsed response"""
    try:
        response = client.messages.create(
            model="claude-sonnet-4-5-20250929",
            max_tokens=500 if use_reasoning else 10,
            system=SYSTEM_PROMPT_WITH_REASONING if use_reasoning else SYSTEM_PROMPT,
            messages=[{
                "role": "user",
                "content": content
            }]
        )
        
        # Extract Claude's answer
        text = ""
        for block in response.content:
            if block.type == "text":
                text += block.text
        text = text.strip()
        
        return text
        
    except Exception as e:
        print(f"Error calling Claude API: {e}")
        return None

def parse_claude_response(text):
    """Parse Claude's response to extract answer letter"""
    import re
    LINE_RX = re.compile(r'^\s*([^,]+)\s*,\s*([A-Ea-e])\s*$', re.UNICODE)
    
    if text:
        first_line = text.splitlines()[0] if text else ""
        m = LINE_RX.match(first_line)
        if m:
            qid_out = m.group(1).strip()
            letter = m.group(2).upper().strip()
            return letter
        else:
            return "PARSE_ERROR"
    else:
        return "NO_RESPONSE"

# Load your Excel data
df = pd.read_excel("../data/subset_with_images.xlsx", sheet_name="SSM_Q_ITA")
picture_link_col = df.columns.get_loc('picture_link') + 1
workbook = openpyxl.load_workbook("../data/subset_with_images.xlsx")
worksheet = workbook["SSM_Q_ITA"]

# Path to your fake image
FAKE_IMAGE_PATH = "../data/Fake_Image_path/image.png"  # UPDATE THIS PATH

# Loop through questions
results = []
skipped_questions = []

for index, row in df.iterrows():
    question_id = row['questionID']
    question_text = row['question_text']
    correct_answer = row['correct_option']
    excel_row = index + 2
    
    # Check if picture_link column exists and get its value
    picture_link = row.get('picture_link', 'N/A')
    has_image = False
    real_image = None
    
    # Try to load real image if available
    if picture_link != 'N/A' and pd.notna(picture_link):
        cell = worksheet.cell(row=excel_row, column=picture_link_col)
        if cell.hyperlink and cell.hyperlink.target:
            try:
                url = cell.hyperlink.target
                file_id = url.split("/d/")[1].split("/")[0]
                download_url = f"https://drive.google.com/uc?export=download&id={file_id}"
                response = requests.get(download_url, timeout=30)
                img = Image.open(BytesIO(response.content))
                
                # Convert RGBA to RGB
                if img.mode in ('RGBA', 'LA'):
                    background = Image.new('RGB', img.size, (255, 255, 255))
                    background.paste(img, mask=img.split()[-1])
                    img = background
                
                real_image = img
                has_image = True
                print(f"Successfully loaded image for question {question_id}")
            except Exception as e:
                print(f"Failed to load image for question {question_id}: {e}")
    
    # Skip questions with invalid correct_option
    if pd.isna(correct_answer) or correct_answer is None:
        print(f"Skipping {question_id}: correct_option is NaN/None")
        skipped_questions.append({
            "question_id": question_id,
            "reason": "correct_option is NaN/None"
        })
        continue

    # Convert to string and handle blanks
    correct_answer_str = str(correct_answer).strip().upper()

    if not correct_answer_str or correct_answer_str not in ['A', 'B', 'C', 'D', 'E']:
        print(f"Skipping {question_id}: Invalid correct_option '{correct_answer}'")
        skipped_questions.append({
            "question_id": question_id,
            "reason": f"Invalid correct_option: {correct_answer}"
        })
        continue
    
    # Build options dictionary
    options = {
        "A": row['option_a'],
        "B": row['option_b'], 
        "C": row['option_c'],
        "D": row['option_d'],
        "E": row['option_e']
    }
    
    # Initialize result dictionary
    result = {
        "question_id": question_id,
        "question": question_text,
        "correct_answer": correct_answer.upper(),
        "has_image": has_image
    }
    
    # If question has image, process with both real and fake images
    if has_image and real_image is not None:
        print(f"\n{'='*60}")
        print(f"Processing question with IMAGE: {question_id}")
        print(f"{'='*60}")
        
        # Build base content
        content_base = build_content_like_main_script(question_id, question_text, options)
        
        # ==== REAL IMAGE ====
        print(f"\n--- Testing with REAL image ---")
        content_real = content_base.copy()
        
        # Add real image
        buffer = BytesIO()
        real_image.save(buffer, format='JPEG')
        image_data_real = base64.b64encode(buffer.getvalue()).decode('utf-8')
        
        content_real.append({
            "type": "image",
            "source": {
                "type": "base64",
                "media_type": "image/jpeg",
                "data": image_data_real
            }
        })
        
        # Call Claude with real image and reasoning
        response_real = call_claude_with_image(content_real, use_reasoning=True)
        
        if response_real:
            print(f"Claude's response with REAL image:\n{response_real}")
            claude_answer_real = parse_claude_response(response_real)
            result["claude_answer_real"] = claude_answer_real
            result["claude_response_real"] = response_real
            result["is_correct_real"] = (correct_answer.upper() == claude_answer_real)
        else:
            result["claude_answer_real"] = "API_ERROR"
            result["claude_response_real"] = "API_ERROR"
            result["is_correct_real"] = False
        
        # ==== FAKE IMAGE ====
        print(f"\n--- Testing with FAKE image ---")
        content_fake = content_base.copy()
        
        # Load and add fake image
        try:
            fake_img = Image.open(FAKE_IMAGE_PATH)
            if fake_img.mode in ('RGBA', 'LA'):
                background = Image.new('RGB', fake_img.size, (255, 255, 255))
                background.paste(fake_img, mask=fake_img.split()[-1])
                fake_img = background
            
            buffer_fake = BytesIO()
            fake_img.save(buffer_fake, format='JPEG')
            image_data_fake = base64.b64encode(buffer_fake.getvalue()).decode('utf-8')
            
            content_fake.append({
                "type": "image",
                "source": {
                    "type": "base64",
                    "media_type": "image/jpeg",
                    "data": image_data_fake
                }
            })
            
            # Call Claude with fake image and reasoning
            response_fake = call_claude_with_image(content_fake, use_reasoning=True)
            
            if response_fake:
                print(f"Claude's response with FAKE image:\n{response_fake}")
                claude_answer_fake = parse_claude_response(response_fake)
                result["claude_answer_fake"] = claude_answer_fake
                result["claude_response_fake"] = response_fake
                result["is_correct_fake"] = (correct_answer.upper() == claude_answer_fake)
            else:
                result["claude_answer_fake"] = "API_ERROR"
                result["claude_response_fake"] = "API_ERROR"
                result["is_correct_fake"] = False
                
        except Exception as e:
            print(f"Error loading fake image: {e}")
            result["claude_answer_fake"] = "FAKE_IMAGE_ERROR"
            result["claude_response_fake"] = f"Error: {e}"
            result["is_correct_fake"] = False
        
        print(f"\n{'='*60}")
        print(f"Correct answer: {correct_answer.upper()}")
        print(f"Claude with REAL: {result.get('claude_answer_real', 'N/A')} {'✓' if result.get('is_correct_real', False) else '✗'}")
        print(f"Claude with FAKE: {result.get('claude_answer_fake', 'N/A')} {'✓' if result.get('is_correct_fake', False) else '✗'}")
        print(f"{'='*60}\n")
        
    else:
        # No image - process normally (optional: you can skip these)
        print(f"Processing question WITHOUT image: {question_id}")
        content = build_content_like_main_script(question_id, question_text, options)
        
        response_text = call_claude_with_image(content, use_reasoning=False)
        
        if response_text:
            claude_answer = parse_claude_response(response_text)
            result["claude_answer"] = claude_answer
            result["is_correct"] = (correct_answer.upper() == claude_answer)
        else:
            result["claude_answer"] = "API_ERROR"
            result["is_correct"] = False
    
    results.append(result)

# Print summary
total_questions = len(results)
questions_with_images = sum(1 for r in results if r.get("has_image", False))
questions_without_images = total_questions - questions_with_images

print(f"\n{'='*60}")
print(f"=== SUMMARY ===")
print(f"{'='*60}")
print(f"Total questions processed: {total_questions}")
print(f"Questions with images: {questions_with_images}")
print(f"Questions without images: {questions_without_images}")
print(f"Questions skipped: {len(skipped_questions)}")

if questions_with_images > 0:
    correct_real = sum(1 for r in results if r.get("is_correct_real", False))
    correct_fake = sum(1 for r in results if r.get("is_correct_fake", False))
    
    accuracy_real = correct_real / questions_with_images * 100
    accuracy_fake = correct_fake / questions_with_images * 100
    
    print(f"\n--- Results with REAL images ---")
    print(f"Correct answers: {correct_real}/{questions_with_images}")
    print(f"Accuracy: {accuracy_real:.1f}%")
    
    print(f"\n--- Results with FAKE images ---")
    print(f"Correct answers: {correct_fake}/{questions_with_images}")
    print(f"Accuracy: {accuracy_fake:.1f}%")

if questions_without_images > 0:
    correct_no_image = sum(1 for r in results if not r.get("has_image", False) and r.get("is_correct", False))
    accuracy_no_image = correct_no_image / questions_without_images * 100
    print(f"\n--- Results WITHOUT images ---")
    print(f"Correct answers: {correct_no_image}/{questions_without_images}")
    print(f"Accuracy: {accuracy_no_image:.1f}%")

# Print skipped questions summary
if skipped_questions:
    print(f"\n=== SKIPPED QUESTIONS ===")
    for skip in skipped_questions:
        print(f"{skip['question_id']}: {skip['reason']}")

# Save results to file
results_df = pd.DataFrame(results)
results_df.to_csv("revision_11_25/claude_results_real_vs_fake_images_11_25_1.csv", index=False)
print(f"\nResults saved to claude_results_real_vs_fake_images_11_25_1.csv")

# Also save skipped questions for reference
if skipped_questions:
    skipped_df = pd.DataFrame(skipped_questions)
    skipped_df.to_csv("revision_11_25/skipped_questions_11_25_1.csv", index=False)
    print(f"Skipped questions saved to skipped_questions_original.csv")
# Out:
# Successfully loaded image for question IT0006
#
# ============================================================
# Processing question with IMAGE: IT0006
# ============================================================
#
# --- Testing with REAL image ---
# Claude's response with REAL image:
# IT0006, C
#
# Reasoning: This ECG shows characteristic features of an anterior wall myocardial infarction:
#
# 1. **ST-segment elevation in precordial leads**: There is clear ST-segment elevation visible in the anterior precordial leads (V1-V6), which is the hallmark of an acute ST-elevation myocardial infarction (STEMI).
#
# 2. **Lead distribution**: The ST elevation is predominantly seen in leads V1 through V6, which correspond to the anterior wall of the left ventricle. The precordial leads overlying the anterior chest wall reflect electrical activity from the anterior myocardium.
#
# 3. **Absence of inferior changes**: Leads II, III, and aVF (inferior leads) do not show the ST elevations that would be expected in an inferior wall MI (option D).
#
# 4. **Regular rhythm with P waves**: The rhythm appears regular with visible P waves preceding QRS complexes, ruling out atrial fibrillation (option B) and third-degree AV block (option E).
#
# 5. **No posterior MI pattern**: A posterior wall MI (option A) would typically show tall R waves and ST depression in V1-V3 (reciprocal changes), which are not evident here.
#
# The pattern of ST-elevation in the anterior precordial leads (V1-V6) is diagnostic of an acute anterior wall myocardial infarction, typically caused by occlusion of the left anterior descending (LAD) coronary artery.
#
# --- Testing with FAKE image ---
# Claude's response with FAKE image:
# IT0006, D
#
# Reasoning: Analyzing the ECG tracing shown in the image, I can observe the following key features:
#
# 1. **ST segment elevation** is present in the inferior leads (II, III, and aVF), which is the hallmark sign of an acute myocardial infarction affecting the inferior wall of the heart.
#
# 2. **Reciprocal ST depression** can be seen in the lateral leads (I and aVL), which further supports the diagnosis of inferior wall MI.
#
# 3. The rhythm appears to be regular sinus rhythm, ruling out atrial fibrillation (option B).
#
# 4. There is no evidence of complete heart block (option E), as P waves are followed by QRS complexes with consistent PR intervals.
#
# 5. The ST elevations are specifically localized to the inferior leads rather than:
#    - Anterior leads (V1-V4) which would indicate anterior MI (option C)
#    - Posterior changes (tall R waves in V1-V2 with ST depression) which would suggest posterior MI (option A)
#
# The distribution of ST elevation in leads II, III, and aVF is pathognomonic for **inferior wall myocardial infarction**, typically caused by occlusion of the right coronary artery or less commonly the left circumflex artery.
#
# ============================================================
# Correct answer: C
# Claude with REAL: C ✓
# Claude with FAKE: D ✗
# ============================================================
#
# Successfully loaded image for question IT0007
#
# ============================================================
# Processing question with IMAGE: IT0007
# ============================================================
#
# --- Testing with REAL image ---
# Claude's response with REAL image:
# IT0007, C
#
# Reasoning: L'ECG mostra i seguenti reperti caratteristici:
#
# 1. **Sopraslivellamento del tratto ST** nelle derivazioni precordiali V1-V6, particolarmente marcato in V2, V3 e V4
# 2. **Coinvolgimento delle derivazioni anteriori** (V1-V6) che indicano un infarto miocardico acuto della parete anteriore
# 3. Le derivazioni I e aVL mostrano anche alterazioni compatibili con un coinvolgimento anterolaterale
#
# **Correlazione anatomica:**
# - L'**arteria discendente anteriore sinistra (LAD)** vascolarizza:
#   - La parete anteriore del ventricolo sinistro
#   - La parte anteriore del setto interventricolare
#   - L'apice cardiaco
#
# - Il pattern ECG con ST sopraslivellato in V1-V6 è **patognomonico** di occlusione della discendente anteriore (LAD)
#
# **Esclusione delle altre opzioni:**
# - **A) Circonflessa**: causerebbe alterazioni nelle derivazioni laterali (I, aVL, V5-V6) e posteriori
# - **B) Sintomi vagali**: potrebbero accompagnare un infarto inferiore (non questo pattern)
# - **D) Discendente posteriore**: causerebbe un infarto inferiore con alterazioni in II, III, aVF
# - **E) Pneumotorace**: presenterebbe altri segni clinici e radiologici, non questo pattern ECG
#
# La risposta corretta è **C** - occlusione dell'arteria discendente anteriore.
#
# --- Testing with FAKE image ---
# Claude's response with FAKE image:
# IT0007, D
#
# Reasoning: La domanda chiede quale condizione il paziente "presenterà probabilmente". Analizzando le opzioni nel contesto di un infarto miocardico acuto:
#
# L'occlusione della discendente posteriore (arteria coronaria destra o suo ramo - l'arteria interventricolare posteriore) è la risposta più appropriata per diversi motivi:
#
# 1. **Correlazione anatomica**: L'arteria discendente posteriore (o interventricolare posteriore) irrora:
#    - Parete inferiore del ventricolo sinistro
#    - Parte del setto interventricolare posteriore
#    - In alcuni casi, parte del ventricolo destro
#
# 2. **Manifestazioni cliniche**: L'infarto inferiore (da occlusione della coronaria destra o della discendente posteriore) si presenta frequentemente con:
#    - Sintomi vagali (bradicardia, nausea, vomito, ipotensione)
#    - Alterazioni ECG nelle derivazioni inferiori (II, III, aVF)
#    - Possibili blocchi AV per compromissione del nodo AV
#
# 3. **Esclusione delle altre opzioni**:
#    - A) Circonflessa: irrora parete laterale
#    - B) Sintomi vagali: sono una conseguenza, non la causa primaria
#    - C) Discendente anteriore: causerebbe infarto anteriore esteso
#    - E) Pneumotorace: non correlato al contesto cardiologico
#
# La risposta D (occlusione della discendente posteriore) rappresenta la causa più probabile dello scenario clinico presentato.
#
# ============================================================
# Correct answer: C
# Claude with REAL: C ✓
# Claude with FAKE: D ✗
# ============================================================
#
# Successfully loaded image for question IT0031
#
# ============================================================
# Processing question with IMAGE: IT0031
# ============================================================
#
# --- Testing with REAL image ---
# Claude's response with REAL image:
# IT0031, A
#
# Reasoning:
#
# La diagnosi più probabile è **Pemfigoide bolloso** basandosi sui seguenti elementi clinici e demografici:
#
# **Fattori chiave dalla storia clinica:**
# 1. **Età**: Paziente di 85 anni - il pemfigoide bolloso colpisce tipicamente anziani (>60-70 anni)
# 2. **Evoluzione**: Inizia con lesioni urticarioidi/eritematose che precedono le bolle - questa è la presentazione classica del pemfigoide bolloso
# 3. **Caratteristiche delle bolle**: Bolle tese a contenuto limpido - indicativo di bolla subepidermica
# 4. **Prurito intenso**: Sintomo cardinale del pemfigoide bolloso
# 5. **Distribuzione diffusa**: Tipica del pemfigoide bolloso
# 6. **Terapia polifarmacologica**: Alcuni farmaci possono scatenare il pemfigoide bolloso
#
# **Analisi dell'immagine:**
# L'immagine mostra multiple bolle tese su base eritematosa, alcune integre, altre erose. Le bolle sono caratteristicamente tese e robuste, non si rompono facilmente - segno distintivo delle bolle subepidermiche del pemfigoide bolloso.
#
# **Esclusione delle altre opzioni:**
# - **B) Pemfigo volgare**: Produce bolle flaccide che si rompono facilmente (intraepidermiche), tipicamente colpisce pazienti più giovani (40-60 anni)
# - **C) Herpes Zoster**: Distribuzione dermatomerica, vescicole raggruppate, dolore più che prurito
# - **D) Dermatite da contatto**: Non causa bolle tese così grandi, avrebbe una relazione con un allergene specifico
# - **E) Impetigine bollosa**: Infezione batterica, più comune in bambini, bolle superficiali che si rompono lasciando croste color miele
#
# --- Testing with FAKE image ---
# Claude's response with FAKE image:
# IT0031, A
#
# Reasoning:
#
# Il caso clinico descrive un paziente anziano (85 anni) con caratteristiche cliniche molto specifiche che orientano verso il pemfigoide bolloso:
#
# **Elementi chiave della diagnosi:**
#
# 1. **Età avanzata**: Il pemfigoide bolloso è la più comune malattia bollosa autoimmune negli anziani, con picco di incidenza dopo i 70 anni.
#
# 2. **Presentazione clinica caratteristica**:
#    - Fase prodromica con placche eritematose orticarioidi
#    - Successiva comparsa di bolle tese a contenuto limpido
#    - Questa progressione è tipica del pemfigoide bolloso
#
# 3. **Bolle tese**: Questo è un elemento distintivo fondamentale. Le bolle nel pemfigoide bolloso sono tese perché la scissione avviene a livello della giunzione dermo-epidermica (subepidermico), mantenendo il tetto epidermico integro.
#
# 4. **Intenso prurito**: Molto caratteristico del pemfigoide bolloso, spesso precede la comparsa delle bolle.
#
# 5. **Fattori predisponenti**: Polifarmacoterapia e patologie neurologiche (ictus pregresso) sono fattori di rischio noti per il pemfigoide bolloso.
#
# **Esclusione delle altre opzioni:**
#
# - **B) Pemfigo volgare**: Presenta bolle flaccide (scissione intraepidermica), non tese, e tipicamente interessa le mucose
# - **C) Herpes Zoster**: Presenta vescicole raggruppate in distribuzione dermatomerica, non bolle diffuse
# - **D) Dermatite da contatto**: Non presenta bolle tese su base eritematosa diffusa
# - **E) Impetigine bollosa**: Più comune nei bambini, con bolle superficiali che si rompono facilmente
#
# ============================================================
# Correct answer: A
# Claude with REAL: A ✓
# Claude with FAKE: A ✓
# ============================================================
#
# Successfully loaded image for question IT0032
#
# ============================================================
# Processing question with IMAGE: IT0032
# ============================================================
#
# --- Testing with REAL image ---
# Claude's response with REAL image:
# IT0032, B
#
# Reasoning:
#
# Questo caso clinico descrive un uomo anziano di 85 anni con:
# - Placche eritematose orticarioidi diffuse
# - Bolle tese a contenuto limpido
# - Prurito intenso
# - Insorgenza recente (un mese)
# - Fattori di rischio: età avanzata, polifarmacoterapia, pregresso ictus
#
# L'immagine mostra bolle tese su base eritematosa, caratteristiche del pemfigoide bolloso.
#
# Il pemfigoide bolloso è la più comune malattia bollosa autoimmune negli anziani, caratterizzata da:
# - Bolle tese e resistenti (a differenza del pemfigo dove sono flaccide)
# - Fase prodromica con placche orticarioidi/eczematiformi
# - Immunopatogenesi: anticorpi IgG anti-membrana basale (anti-BP180 e anti-BP230)
#
# Analisi delle opzioni:
#
# A) Anticorpi anti-gliadina e anti-transglutaminasi: indicati per dermatite erpetiforme (associata a celiachia), che però presenta tipicamente vescicole raggruppate, non bolle tese
#
# B) **CORRETTA**: Biopsia con istologia e immunofluorescenza diretta (DIF) + ricerca anticorpi anti-membrana basale. La DIF mostra depositi lineari di IgG e C3 lungo la membrana basale, diagnostici per pemfigoide bolloso
#
# C) Dermatoscopia: non appropriata per diagnosi di malattie bollose autoimmuni
#
# D) Test di Tzanck: utile per infezioni erpetiche (cellule giganti multinucleate), non per patologie autoimmuni
#
# E) Anticorpi anti-desmogleina 1 e 3: specifici per il PEMFIGO (volgare o foliaceo), dove le bolle sono flaccide e si rompono facilmente, non per il pemfigo
#
# --- Testing with FAKE image ---
# Claude's response with FAKE image:
# IT0032, B
#
# Reasoning:
#
# This clinical case describes an 85-year-old man with:
# - Risk factors: previous ischemic stroke, diabetes, polypharmacy
# - Clinical presentation: urticarial erythematous plaques for about one month, followed by tense bullae with clear content, intensely pruritic
#
# This presentation is highly suggestive of **Bullous Pemphigoid (BP)**, which is:
# - The most common autoimmune blistering disease in elderly patients
# - Characterized by tense bullae (due to subepidermal split)
# - Often preceded by urticarial/eczematous prodromal phase
# - Associated with pruritus
# - Risk factors include advanced age, neurological diseases, and certain medications
#
# The appropriate diagnostic workup for Bullous Pemphigoid includes:
# 1. **Skin biopsy for histology**: Shows subepidermal blister
# 2. **Direct immunofluorescence (DIF)**: Shows linear IgG and C3 deposits along the basement membrane zone
# 3. **Serology**: Detection of circulating anti-basement membrane zone antibodies (anti-BP180 and anti-BP230)
#
# **Analysis of options:**
# - **A**: Anti-gliadin and anti-transglutaminase antibodies are for celiac disease/dermatitis herpetiformis - not consistent with tense bullae
# - **B**: CORRECT - This is the appropriate workup for bullous pemphigoid
# - **C**: Dermatoscopy is not the primary diagnostic tool for autoimmune blistering diseases
# - **D**: Tzanck smear is useful for viral infections (herpes, varicella) showing acantholytic cells - not appropriate here
# - **E**: Anti-desmoglein 1 and 3 antibodies are specific for pemphigus (intraepidermal blistering), not pemphigoid (subepidermal blistering)
#
# ============================================================
# Correct answer: B
# Claude with REAL: B ✓
# Claude with FAKE: B ✓
# ============================================================
#
# Successfully loaded image for question IT0053
#
# ============================================================
# Processing question with IMAGE: IT0053
# ============================================================
#
# --- Testing with REAL image ---
# Claude's response with REAL image:
# IT0053, C
#
# Reasoning: Questo è uno studio caso-controllo sul cancro dell'esofago e consumo di superalcolici. La tabella mostra:
# - 870 casi (malati) e 902 controlli (non malati)
# - Tra gli esposti: 656 malati e 516 non malati
# - Tra i non esposti: 214 malati e 386 non malati
#
# In uno studio caso-controllo, la misura di associazione appropriata è l'**Odds Ratio (OR)**, non il Rischio Relativo (RR) o il Rischio Attribuibile (RA), poiché:
# 1. Non possiamo calcolare l'incidenza diretta (i casi sono selezionati, non seguiti nel tempo)
# 2. L'OR è la misura valida per gli studi caso-controllo
#
# La formula corretta dell'OR è:
# OR = (a × d) / (b × c)
#
# Dove nella tabella 2×2:
# - a = esposti e malati = 656
# - b = esposti e non malati = 516
# - c = non esposti e malati = 214
# - d = non esposti e non malati = 386
#
# Quindi: OR = (656 × 386) / (516 × 214)
#
# Questa formula corrisponde esattamente all'**opzione C**.
#
# Le altre opzioni sono errate perché:
# - A ed E: Calcolano il RA (Rischio Attribuibile), inappropriato per studi caso-controllo
# - B: Calcola il RR, che non può essere stimato direttamente in studi caso-controllo
# - D: Formula incompleta dell'OR (manca il rapporto con il secondo prodotto)
#
# --- Testing with FAKE image ---
# Claude's response with FAKE image:
# IT0053, C
#
# Reasoning:
#
# This question asks about the appropriate measure of association between esophageal cancer and alcohol consumption in a case-control study design.
#
# Key considerations:
#
# 1. **Study Design**: This is explicitly a case-control study (studio caso-controllo) with 870 cases and 902 controls.
#
# 2. **Appropriate Measure for Case-Control Studies**:
#    - In case-control studies, we cannot calculate relative risk (RR) directly because we cannot determine incidence rates - the number of cases and controls are fixed by the study design, not by natural occurrence
#    - The odds ratio (OR) is the appropriate measure of association for case-control studies
#    - Risk difference (RA - attributable risk) also requires incidence data, which is not available in case-control studies
#
# 3. **Odds Ratio Formula**:
#    OR = (a × d) / (b × c)
#    Where in a 2×2 table:
#    - a = exposed cases (656)
#    - b = exposed controls (214)
#    - c = unexposed cases (516)
#    - d = unexposed controls (386)
#
# 4. **Evaluating the Options**:
#    - Option A: RA calculation - inappropriate for case-control
#    - Option B: RR calculation - inappropriate for case-control
#    - **Option C: OR = (656 × 386) / (516 × 214)** - correct formula for odds ratio
#    - Option D: OR = 656/386 - incorrect formula
#    - Option E: RA calculation - inappropriate for case-control
#
# The correct answer is C, which provides the proper odds ratio calculation for a case-control study.
#
# ============================================================
# Correct answer: C
# Claude with REAL: C ✓
# Claude with FAKE: C ✓
# ============================================================
#
# Successfully loaded image for question IT0054
#
# ============================================================
# Processing question with IMAGE: IT0054
# ============================================================
#
# --- Testing with REAL image ---
# Claude's response with REAL image:
# IT0054, A
#
# Reasoning:
#
# La domanda chiede quale sia generalmente indicato tra i vantaggi degli studi caso-controllo.
#
# Analizziamo le opzioni:
#
# **A) Il relativo basso costo e la breve durata** - CORRETTO
# Questo è uno dei principali vantaggi riconosciuti degli studi caso-controllo:
# - Sono retrospettivi, quindi non richiedono lunghi periodi di follow-up
# - Richiedono campioni più piccoli rispetto agli studi di coorte
# - Sono particolarmente utili per malattie rare (come il cancro dell'esofago in questo caso)
# - Hanno costi contenuti rispetto agli studi prospettici
#
# **B) La possibilità di calcolare l'incidenza periodale** - ERRATO
# Gli studi caso-controllo NON permettono di calcolare l'incidenza perché:
# - I casi sono selezionati a priori (non seguiti nel tempo)
# - Non si conosce la popolazione a rischio
# - Il rapporto casi/controlli è arbitrario
#
# **C) La possibilità di calcolare la prevalenza puntuale** - ERRATO
# Gli studi caso-controllo non permettono di calcolare la prevalenza perché il numero di casi e controlli è predeterminato dal disegno dello studio, non rappresenta la distribuzione naturale nella popolazione.
#
# **D) La possibilità di calcolare la prevalenza periodale** - ERRATO
# Per le stesse ragioni dell'opzione C.
#
# **E) La possibilità di calcolare l'incidenza** - ERRATO
# Per le stesse ragioni dell'opzione B.
#
# Gli studi caso-controllo permettono invece di calcolare l'**odds ratio (OR)**, che è una misura di associazione tra esposizione e malattia, ma non misure di frequenza dirette come incidenza o prevalenza.
#
# --- Testing with FAKE image ---
# Claude's response with FAKE image:
# IT0054, A
#
# Reasoning: This question asks about the general advantages of case-control studies, using an example of a study investigating the etiology of esophageal cancer.
#
# Let me analyze each option:
#
# **Option A - Relatively low cost and short duration:**
# This is a well-established advantage of case-control studies. They are retrospective by design, meaning they look backward in time from effect (disease) to exposure. Researchers identify cases (people with the disease) and controls (people without the disease) at the start, then investigate past exposures. This requires fewer resources and less time compared to prospective cohort studies that follow people forward in time.
#
# **Options B, D, E - Calculate incidence (periodic or otherwise):**
# Case-control studies CANNOT calculate incidence. Incidence requires following a disease-free population over time to count new cases. In case-control studies, cases are selected based on already having the disease, so the temporal sequence needed for incidence calculation is disrupted.
#
# **Option C - Calculate point prevalence:**
# Case-control studies also cannot calculate prevalence reliably. Prevalence studies require representative sampling of a defined population at a specific time point. Case-control studies deliberately oversample cases to improve statistical power, creating a non-representative sample that distorts prevalence estimates.
#
# The primary strength of case-control studies is their efficiency - they are particularly useful for studying rare diseases or diseases with long latency periods (like cancer) because they:
# - Don't require following large populations for years
# - Can be completed relatively quickly
# - Require fewer resources than cohort studies
# - Are ideal for generating hypotheses about disease etiology
#
# **Answer: A** is correct as it accurately identifies the key practical advantages of case-control study design.
#
# ============================================================
# Correct answer: A
# Claude with REAL: A ✓
# Claude with FAKE: A ✓
# ============================================================
#
# Successfully loaded image for question IT0063
#
# ============================================================
# Processing question with IMAGE: IT0063
# ============================================================
#
# --- Testing with REAL image ---
# Claude's response with REAL image:
# IT0063, C
#
# Reasoning:
#
# Clinical context:
# - 48-year-old male smoker with hypertension
# - Presenting with epigastric pain for 6 hours (classic for inferior MI)
# - Hypotensive (BP 90/50 mmHg) - suggesting hemodynamic compromise
# - Bradycardic (HR 57/min) - suggesting possible AV nodal involvement
# - On ACE inhibitor therapy
#
# ECG Analysis:
# Looking at the provided ECG image, I can identify the following key findings:
#
# 1. **Inferior leads (II, III, aVF)**: There is clear ST-segment elevation visible in leads II, III, and aVF. This is the hallmark of inferior wall STEMI.
#
# 2. **Lead aVL**: Shows reciprocal ST-segment depression, which is typical for inferior MI.
#
# 3. **Precordial leads (V1-V6)**: Do not show significant ST elevation that would suggest anterior involvement. V2 and V3 do not show the tall R waves or ST changes typical of anterior STEMI.
#
# 4. **No diffuse ST elevation**: This rules out pericarditis (option B), which typically shows widespread ST elevation with PR depression.
#
# 5. **No pathological Q waves in anterior leads**: This makes option D (probable previous anterior infarction) unlikely.
#
# The combination of:
# - ST elevation in inferior leads (II, III, aVF)
# - Reciprocal changes in aVL
# - Epigastric pain (common presentation of inferior MI)
# - Bradycardia (due to RCA involvement affecting SA/AV node)
# - Hypotension (possible RV involvement or cardiogenic shock)
#
# All point definitively to an **acute inferior wall STEMI (ST-Elevation Myocardial Infarction)**.
#
# --- Testing with FAKE image ---
# Claude's response with FAKE image:
# IT0063, C
#
# Reasoning: Analizzando il caso clinico e l'ECG:
#
# **Dati clinici chiave:**
# - Uomo 48 anni, fumatore (fattore di rischio cardiovascolare)
# - Iperteso in terapia con ACE inibitore
# - Dolore epigastrico da 6 ore (presentazione atipica ma compatibile con infarto)
# - PA 90/50 mmHg (ipotensione suggestiva di infarto con compromissione emodinamica)
# - FC 57/min (bradicardia, tipica dell'infarto inferiore per coinvolgimento del nodo AV)
# - SatO2 99% (normale)
#
# **Analisi dell'ECG:**
# Sebbene l'immagine non sia perfettamente nitida, le caratteristiche cliniche orientano fortemente verso uno STEMI inferiore:
#
# 1. **Bradicardia sinusale (FC 57/min)**: Comune negli infarti inferiori per stimolazione vagale e coinvolgimento del nodo SA/AV (irrorato dall'arteria coronaria destra nel 90% dei casi)
#
# 2. **Ipotensione**: Suggestiva di infarto del ventricolo destro (complicanza frequente dello STEMI inferiore) o di esteso coinvolgimento inferiore
#
# 3. **Dolore epigastrico**: Presentazione atipica ma caratteristica dell'infarto della parete inferiore per vicinanza anatomica al diaframma
#
# 4. **Derivazioni interessate**: Nello STEMI inferiore ci aspettiamo sopraslivellamento ST in DII, DIII, aVF
#
# **Esclusione altre opzioni:**
# - A, E: STEMI anteriore/antero-laterale causerebbe più tipicamente tachicardia compensatoria, non bradicardia
# - B: Pericardite non spiegherebbe l'ipotensione e bradicardia marcate
# - D: Qua
#
# ============================================================
# Correct answer: C
# Claude with REAL: C ✓
# Claude with FAKE: C ✓
# ============================================================
#
# Successfully loaded image for question IT0064
#
# ============================================================
# Processing question with IMAGE: IT0064
# ============================================================
#
# --- Testing with REAL image ---
# Claude's response with REAL image:
# IT0064, D
#
# Reasoning: This case presents a 48-year-old hypertensive smoker with:
# - Epigastric pain for 6 hours
# - Hypotension (BP 90/50 mmHg)
# - Bradycardia (HR 57/min)
# - Normal oxygen saturation (99%)
#
# The ECG shows classic findings of an **inferior ST-elevation myocardial infarction (STEMI)**:
# - ST elevation in leads II, III, and aVF (inferior leads)
# - Reciprocal ST depression in leads I and aVL
# - The bradycardia is consistent with inferior MI involving the right coronary artery, which can affect the SA and AV nodes
#
# The patient is being prepared for emergency cardiac catheterization (hemodynamics lab alert), indicating urgent revascularization for STEMI.
#
# **Analysis of options:**
#
# A) **Nitroprussiato di sodio** - Contraindicated. This is a vasodilator that would worsen hypotension in this already hypotensive patient.
#
# B) **Diltiazem** - Contraindicated. A calcium channel blocker would worsen bradycardia and hypotension, both already present.
#
# C) **Warfarin** - Inappropriate for acute STEMI management. Takes days to work and is not part of acute coronary syndrome protocols.
#
# D) **Ticagrelor** - CORRECT. This is a P2Y12 inhibitor antiplatelet agent that is essential in acute STEMI management. Current guidelines recommend dual antiplatelet therapy (aspirin + P2Y12 inhibitor like ticagrelor) as soon as possible in STEMI patients undergoing primary PCI.
#
# E) **Enalapril** - While ACE inhibitors are beneficial post-MI, they are contraindicated in the acute phase when the patient is hypotensive (BP 90/50).
#
# The immediate management while awaiting catheterization should include antiplatelet therapy with ticagrelor (loading dose) along with aspirin to prevent further thrombosis and improve outcomes.
#
# --- Testing with FAKE image ---
# Claude's response with FAKE image:
# IT0064, D
#
# Reasoning: This case describes a 48-year-old hypertensive smoker presenting with epigastric pain for 6 hours, hypotension (BP 90/50 mmHg), and bradycardia (HR 57/min). The clinical picture and mention of alerting the catheterization lab strongly suggest an acute myocardial infarction requiring urgent percutaneous coronary intervention (PCI).
#
# Let me analyze each option:
#
# A) **Nitroprussiato di sodio (Sodium nitroprusside)** - This is a potent vasodilator used for hypertensive emergencies. The patient is already hypotensive (90/50 mmHg), making this contraindicated as it would further decrease blood pressure.
#
# B) **Diltiazem** - This is a calcium channel blocker that can cause bradycardia and hypotension. The patient already has bradycardia (57/min) and hypotension, making this inappropriate.
#
# C) **Warfarin** - This is an oral anticoagulant that takes days to become effective. It has no role in acute MI management and is not used in the acute setting before PCI.
#
# D) **Ticagrelor** - This is a P2Y12 inhibitor (antiplatelet agent) that is a cornerstone of acute coronary syndrome management. Current guidelines recommend dual antiplatelet therapy (DAPT) with aspirin plus a P2Y12 inhibitor (ticagrelor or prasugrel) as soon as possible in STEMI patients undergoing primary PCI. Ticagrelor has a rapid onset of action and is preferred in acute settings.
#
# E) **Enalapril** - This is an ACE inhibitor. The patient is already on an ACE inhibitor, and administering another dose in the setting of hypotension would be dangerous and potentially worsen the hemodynamic status.
#
# Given the acute MI scenario requiring urgent catheterization, the most appropriate medication to initiate is antiplatelet therapy with ticagrelor to prevent further thrombosis and improve outcomes during PCI.
#
# ============================================================
# Correct answer: D
# Claude with REAL: D ✓
# Claude with FAKE: D ✓
# ============================================================
#
# Successfully loaded image for question IT0065
#
# ============================================================
# Processing question with IMAGE: IT0065
# ============================================================
#
# --- Testing with REAL image ---
# Claude's response with REAL image:
# IT0065, A
#
# Reasoning:
#
# Analyzing the clinical presentation and ECG:
#
# **Clinical Context:**
# - 48-year-old male, smoker, hypertensive
# - Epigastric pain for 6 hours (classic MI presentation)
# - Hypotension (BP 90/50 mmHg) - suggests significant hemodynamic compromise
# - Bradycardia (HR 57/min) - suggests possible AV nodal involvement
# - This combination suggests right coronary artery (RCA) involvement
#
# **ECG Analysis:**
# Looking at the provided ECG image:
#
# 1. **Inferior leads (II, III, aVF):** Show clear ST-segment elevation
#    - Lead II: ST elevation visible
#    - Lead III: Marked ST elevation
#    - Lead aVF: ST elevation present
#
# 2. **Reciprocal changes:** ST depression appears in leads I and aVL (lateral leads), which is characteristic of inferior STEMI
#
# 3. **Precordial leads (V1-V6):** No significant ST elevation in anterior leads
#
# **Key Diagnostic Points:**
#
# The combination of:
# - ST elevation in inferior leads (II, III, aVF)
# - Bradycardia (57 bpm)
# - Hypotension
# - No anterior ST elevation
#
# This pattern is pathognomonic for **inferior wall myocardial infarction**.
#
# **Coronary Anatomy:**
# - The **right coronary artery (RCA)** supplies:
#   - Inferior wall of left ventricle (80-90% of cases)
#   - SA node (60% of people)
#   - AV node (90% of people)
#   - Right ventricle
#
# The bradycardia and hypotension with inferior STEMI strongly suggest RCA occlusion with:
# - AV nodal ischemia causing bradycardia
# - Right ventricular involvement causing hypotension
#
# **Answer: A) Coronaria destra (Right Coronary Artery)**
#
# --- Testing with FAKE image ---
# Claude's response with FAKE image:
# IT0065, A
#
# Reasoning: Il paziente presenta un quadro clinico altamente suggestivo di infarto miocardico acuto inferiore con interessamento dell'arteria coronaria destra:
#
# 1. **Profilo clinico**: Uomo di 48 anni con fattori di rischio cardiovascolari (fumatore, ipertensione) che presenta dolore epigastrico acuto da 6 ore.
#
# 2. **Parametri emodinamici critici**:
#    - **Ipotensione** (PA 90/50 mmHg): suggerisce compromissione emodinamica
#    - **Bradicardia** (FC 57/min): caratteristica dell'infarto inferiore per coinvolgimento del nodo SA/AV
#
# 3. **Correlazione anatomica**:
#    - L'arteria **coronaria destra** irrora:
#      * Parete inferiore del ventricolo sinistro
#      * Nodo seno-atriale (nel 60% dei casi)
#      * Nodo atrio-ventricolare (nell'85-90% dei casi)
#
# 4. **Triade tipica dell'infarto da coronaria destra**:
#    - Dolore epigastrico (può essere manifestazione atipica)
#    - Ipotensione (da ridotta precarica per coinvolgimento ventricolare destro)
#    - Bradicardia (da ischemia del sistema di conduzione)
#
# 5. **Esclusione delle altre opzioni**:
#    - **Discendente anteriore (E)**: causerebbe infarto anteriore con più facilmente tachicardia compensatoria
#    - **Circonflessa/margine ottuso (B)**: infarto laterale, meno probabile bradicardia
#    - **Tronco comune (D)**: presentazione catastrofica con shock cardiogeno severo
#    - **Coronaria sinistra (C)**: troppo generico
#
# L'ECG (sebbene l'immagine non sia chiaramente vis
#
# ============================================================
# Correct answer: A
# Claude with REAL: A ✓
# Claude with FAKE: A ✓
# ============================================================
#
# Successfully loaded image for question IT0095
#
# ============================================================
# Processing question with IMAGE: IT0095
# ============================================================
#
# --- Testing with REAL image ---
# Claude's response with REAL image:
# IT0095, C
#
# Reasoning:
#
# The clinical scenario describes a 23-year-old male involved in a high-velocity motorcycle accident with the following key findings:
#
# **Clinical Assessment (Glasgow Coma Scale):**
# - Eyes: Does not open to verbal or painful stimuli (E1)
# - Verbal: No speech (V1)
# - Motor: Withdraws from painful stimuli (M4)
# - **Total GCS = 6** (severe head injury)
#
# **Critical Finding:**
# - **Anisocoria with right pupil > left pupil** - This indicates uncal herniation with compression of the right oculomotor nerve (CN III), suggesting a mass effect on the right side causing brain herniation.
#
# **CT Image Analysis:**
# The CT scan shows a **biconvex (lens-shaped) hyperdense collection** in the right temporoparietal region that does not cross suture lines, characteristic of an **epidural hematoma**.
#
# **Why Epidural Hematoma (Option C)?**
#
# 1. **Mechanism**: High-velocity motorcycle trauma commonly causes temporal bone fractures with laceration of the middle meningeal artery
#
# 2. **Clinical presentation**:
#    - Rapid deterioration
#    - Ipsilateral pupillary dilation (anisocoria right > left)
#    - Signs of increased intracranial pressure and herniation
#
# 3. **CT appearance**:
#    - Biconvex/lenticular shape (limited by suture lines where dura is attached to skull)
#    - Hyperdense acute blood collection
#    - Does not cross suture lines
#    - Associated mass effect
#
# 4. **Age**: Young patient involved in high-velocity trauma is classic for epidural hematoma
#
# **Why not the others?**
# - **A (Intraparenchimale)**: Would show blood within brain tissue, different appearance
# - **B (Subdural cronico)**: Would be hypodense/isodense, not acute presentation
# - **D (Subdural acuto)**: Would be crescentic, crosses suture lines
# - **E (Subgaleale)**: External to skull, wouldn't cause these neurological signs
#
# --- Testing with FAKE image ---
# Claude's response with FAKE image:
# IT0095, C
#
# Reasoning:
#
# Analizziamo il caso clinico:
#
# **Scenario**: Giovane di 23 anni, trauma cranico da incidente motociclistico (trauma ad alta energia)
#
# **Esame obiettivo neurologico (Glasgow Coma Scale)**:
# - Apertura occhi: nessuna risposta = 1
# - Risposta verbale: assente = 1
# - Risposta motoria: retrazione allo stimolo doloroso = 4
# - **GCS totale = 6** (grave trauma cranico)
#
# **Elemento chiave**: **Anisocoria con destra > sinistra**
#
# L'anisocoria in un paziente con trauma cranico indica compressione del nervo oculomotore (III nervo cranico) omolaterale, suggerendo un'erniazione cerebrale uncale dovuta a effetto massa.
#
# **Diagnosi differenziale degli ematomi traumatici**:
#
# 1. **Ematoma epidurale** (C):
#    - Tipico in traumi ad alta energia nei giovani
#    - Rottura dell'arteria meningea media
#    - Classico "intervallo libero" seguito da deterioramento rapido
#    - Forma lenticolare/biconvessa alla TC
#    - Può causare rapida compressione con anisocoria
#    - **Compatibile con il caso**
#
# 2. **Ematoma sottodurale acuto** (D):
#    - Possibile, ma meno tipico per l'età
#    - Forma a semiluna alla TC
#    - Spesso associato a lesioni parenchimali
#
# 3. **Ematoma sottodurale cronico** (B):
#    - Escluso: richiede settimane per svilupparsi
#    - Tipico degli anziani
#
# 4. **Ematoma intraparenchimale** (A):
#    - Possibile ma meno probabile come lesione primaria che causa anisocoria acuta
#
# 5. **Ematoma subgaleale** (E
#
# ============================================================
# Correct answer: C
# Claude with REAL: C ✓
# Claude with FAKE: C ✓
# ============================================================
#
# Successfully loaded image for question IT0111
#
# ============================================================
# Processing question with IMAGE: IT0111
# ============================================================
#
# --- Testing with REAL image ---
# Claude's response with REAL image:
# IT0111, B
#
# Reasoning:
#
# Analyzing the clinical presentation:
# - 37-year-old male with severe shoulder pain
# - Fall on the palm of the hand with the shoulder in moderate abduction and extension
# - This is a classic mechanism for anterior shoulder dislocation (fall on outstretched hand - FOOSH injury)
#
# Examining the radiographic image:
# This appears to be an AP or axillary view of the shoulder that shows:
# 1. The humeral head is displaced anteriorly and inferiorly relative to the glenoid fossa
# 2. There is loss of the normal relationship between the humeral head and glenoid cavity
# 3. The humeral head appears to be positioned inferior to the coracoid process (subcoracoid position), which is the most common location for anterior dislocations
# 4. The characteristic "light bulb" sign may be present (fixed internal rotation of the humerus)
#
# Key differential considerations:
# - **Anterior glenohumeral dislocation (B)**: Most common shoulder dislocation (>95%), typically caused by FOOSH with arm in abduction and external rotation. The radiograph shows anterior displacement of humeral head.
# - Posterior dislocation (E): Rare (<5%), usually from seizures or electric shock, would show different positioning
# - Acromioclavicular dislocation (C): Would affect the AC joint superiorly, not the glenohumeral joint
# - Greater tuberosity fracture (A): Can accompany anterior dislocation but is not the primary diagnosis here
# - Glenoid fracture (D): Not evident on this image
#
# The mechanism of injury (fall on extended arm) and radiographic findings are pathognomonic for **anterior glenohumeral dislocation**.
#
# --- Testing with FAKE image ---
# Claude's response with FAKE image:
# IT0111, B
#
# Reasoning:
#
# Il caso clinico descrive un uomo di 37 anni con dolore intenso alla spalla destra dopo una caduta sul palmo della mano con la spalla in modica abduzione ed estensione.
#
# Analisi del meccanismo traumatico:
# - Caduta sul palmo della mano (FOOSH - Fall On OutStretched Hand)
# - Spalla in abduzione ed estensione
# - Questo è il meccanismo classico per la lussazione anteriore gleno-omerale
#
# Considerazioni diagnostiche:
#
# **Lussazione anteriore gleno-omerale (B)**: È la lussazione più comune della spalla (>95% di tutte le lussazioni). Il meccanismo traumatico descritto (caduta con spalla abdotta ed extraruotata/estesa) è TIPICO per questo tipo di lesione. La testa omerale si disloca anteriormente rispetto alla glenoide.
#
# **Lussazione posteriore (E)**: Rappresenta solo il 2-4% delle lussazioni. Richiede un meccanismo diverso: trauma diretto posteriore, convulsioni, o elettrocuzione. NON compatibile con il meccanismo descritto.
#
# **Frattura del trochite (A)**: Può accompagnare una lussazione anteriore ma raramente è la lesione principale da questo meccanismo.
#
# **Lussazione acromion-claveare (C)**: Richiede trauma diretto sulla spalla o caduta sulla spalla stessa, non sul palmo della mano.
#
# **Frattura della glenoide (D)**: Rara e solitamente associata a traumi ad alta energia, non compatibile con la presentazione clinica.
#
# La diagnosi più probabile basata sul meccanismo traumatico classico è la **lussazione anteriore gleno-omerale**.
#
# ============================================================
# Correct answer: B
# Claude with REAL: B ✓
# Claude with FAKE: B ✓
# ============================================================
#
# Successfully loaded image for question IT0130
#
# ============================================================
# Processing question with IMAGE: IT0130
# ============================================================
#
# --- Testing with REAL image ---
# Claude's response with REAL image:
# IT0130, A
#
# Reasoning: The image shows an MRI of the lumbar spine viewed from a lateral perspective, displaying the vertebral bodies, intervertebral discs, spinal canal, and the anterior-posterior relationship of structures. This is characteristic of a **pure sagittal plane** view.
#
# Key features that identify this as a pure sagittal plane:
# 1. **Midline sagittal orientation**: The image shows the spine cut from side to side, displaying the full length of multiple vertebral bodies stacked vertically
# 2. **Visualization of structures**: We can clearly see the vertebral bodies, intervertebral discs, spinal canal, and the natural lordotic curve of the lumbar spine
# 3. **Anterior-posterior relationships**: The image shows the relationship between anterior (vertebral bodies) and posterior (spinal canal, spinous processes) structures
# 4. **Not oblique**: If this were an oblique sagittal plane (options D or E), we would see structures like the pedicles (option D) or neural foramina (option E) more prominently, which are better visualized on parasagittal or oblique cuts
# 5. **Not coronal or axial**: Option B (coronal) would show a front-to-back view, and option C (axial) would show a cross-sectional view from above
#
# This is a standard **pure sagittal plane** MRI sequence commonly used as the primary view for evaluating lumbar spine pathology, including disc herniation, spinal stenosis, and vertebral alignment.
#
# --- Testing with FAKE image ---
# Claude's response with FAKE image:
# IT0130, E
#
# Reasoning: L'immagine mostra una risonanza magnetica del rachide lombare acquisita su un piano sagittale obliquo specificamente orientato per lo studio dei forami di coniugazione (o forami intervertebrali).
#
# Le caratteristiche che permettono di identificare questo piano sono:
#
# 1. **Orientamento sagittale obliquo**: L'immagine non è un piano sagittale puro mediano (che mostrerebbe i corpi vertebrali centralmente e il canale spinale), né un piano coronale o assiale.
#
# 2. **Visualizzazione dei forami di coniugazione**: Questo piano obliquo è angolato lateralmente rispetto al piano sagittale mediano ed è specificamente progettato per visualizzare i forami intervertebrali dove emergono le radici nervose.
#
# 3. **Scopo clinico**: Nel contesto di lombalgia persistente non responsiva ai FANS, lo studio dei forami di coniugazione è essenziale per valutare eventuali stenosi foraminali, ernie discali laterali o compressioni radicolari che potrebbero spiegare la sintomatologia del paziente.
#
# 4. **Differenza dal piano D**: Il piano sagittale obliquo per lo studio dei peduncoli (opzione D) ha un'angolazione diversa e mostra principalmente i peduncoli vertebrali e le articolazioni interapofisarie, non specificamente i forami di coniugazione.
#
# ============================================================
# Correct answer: A
# Claude with REAL: A ✓
# Claude with FAKE: E ✗
# ============================================================
#
# Successfully loaded image for question IT0131
#
# ============================================================
# Processing question with IMAGE: IT0131
# ============================================================
#
# --- Testing with REAL image ---
# Claude's response with REAL image:
# IT0131, A
#
# Reasoning: The question asks about the most appropriate investigation to identify the presence of bone metastases in a 45-year-old patient whose lumbar spine MRI (performed for 2-month non-responsive low back pain) revealed a probable bone metastasis.
#
# When a localized bone metastasis is found and there's a need to screen the entire skeleton for additional metastatic lesions, the following considerations apply:
#
# **A) Bone scintigraphy (Scintigrafia ossea)** - This is the gold standard for whole-body skeletal survey for metastases. It's highly sensitive for detecting osteoblastic and mixed metastatic lesions throughout the entire skeleton in a single examination. It's cost-effective, widely available, and can detect lesions before they're visible on plain radiographs. It provides a comprehensive whole-body skeletal assessment.
#
# **B) CT of the entire spine** - Limited to the spine only, would miss metastases in ribs, pelvis, long bones, skull, etc.
#
# **C) CT of entire skeleton with contrast** - Not standard practice; involves high radiation dose, expensive, time-consuming, and contrast isn't particularly helpful for bone metastases.
#
# **D) Selective ultrasound of suspicious skeletal regions** - Ultrasound has very limited utility in detecting bone metastases; bone blocks ultrasound waves, making it inappropriate for this indication.
#
# **E) Low-dose CT of entire skeleton** - While whole-body low-dose CT is emerging, it's not the standard first-line investigation and involves more radiation than bone scintigraphy.
#
# Given that a probable metastasis has been identified in the lumbar spine, the next step is to perform a whole-body skeletal survey to stage the extent of metastatic disease. Bone scintigraphy remains the most appropriate, sensitive, and cost-effective method for this purpose.
#
# --- Testing with FAKE image ---
# Claude's response with FAKE image:
# IT0131, A
#
# Reasoning: La domanda riguarda quale indagine sia più appropriata per identificare la presenza di metastasi ossee in un paziente di 45 anni con sospetta metastasi ossea rilevata alla RM lombare.
#
# Analizziamo le opzioni:
#
# A) **Scintigrafia ossea** - È considerata l'esame di screening gold standard per la ricerca di metastasi ossee in tutto lo scheletro. Utilizza radiofarmaci (tecnezio-99m) che si concentrano nelle aree di aumentato turnover osseo, permettendo di visualizzare l'intero scheletro in un unico esame. Ha alta sensibilità per lesioni osteoblastiche e miste, è relativamente economica e ampiamente disponibile.
#
# B) **TC del rachide in toto** - Limita l'indagine solo alla colonna vertebrale, non valutando altri siti scheletrici dove potrebbero esserci metastasi (bacino, costole, ossa lunghe, cranio).
#
# C) **TC dello scheletro in toto con mezzo di contrasto** - Comporterebbe un'esposizione radiante molto elevata e non è l'approccio standard per lo screening delle metastasi ossee. Il mezzo di contrasto non aggiunge valore significativo nella valutazione ossea.
#
# D) **Esame ecografico** - L'ecografia ha limitazioni significative nella valutazione dello scheletro profondo e non è appropriata per uno screening completo delle metastasi ossee.
#
# E) **TC a bassa dose** - Anche se riduce l'esposizione, la TC non è l'esame di prima scelta per lo screening delle metastasi ossee rispetto alla scintigrafia.
#
# La scintigrafia ossea total body è l'indagine più appropriata perché permette uno screening completo di tutto lo scheletro con un singolo esame, ha alta sensibilità ed è cost-effective per questa indicazione clinica.
#
# ============================================================
# Correct answer: A
# Claude with REAL: A ✓
# Claude with FAKE: A ✓
# ============================================================
#
# Successfully loaded image for question IT0136
#
# ============================================================
# Processing question with IMAGE: IT0136
# ============================================================
#
# --- Testing with REAL image ---
# Claude's response with REAL image:
# IT0136, B
#
# Reasoning: La paziente è una donna di 19 anni con addominalgia e diarrea postprandiali, sintomi che suggeriscono un malassorbimento. L'esofagogastroduodenoscopia è stata eseguita per indagare questa condizione.
#
# Analizzando l'immagine endoscopica:
# - Si osserva una perdita delle pieghe duodenali normali
# - La mucosa appare appiattita e liscia
# - Non sono visibili le normali villosità intestinali
# - La superficie ha un aspetto "a mosaico" o scalloping delle pieghe
# - Non ci sono ulcere evidenti
# - Non c'è sanguinamento attivo
# - Non sono visibili masse o neoformazioni
# - Non ci sono fistole o ascessi visibili
#
# Questi reperti sono caratteristici dell'**atrofia della mucosa duodenale**, tipicamente osservata nella malattia celiaca o in altre condizioni che causano malassorbimento. La perdita delle villosità intestinali (atrofia villare) è responsabile del malassorbimento e dei sintomi postprandiali della paziente.
#
# Il contesto clinico (giovane donna con sintomi di malassorbimento) insieme ai reperti endoscopici di mucosa appiattita e priva delle normali caratteristiche villose conferma l'atrofia della mucosa come reperto principale.
#
# --- Testing with FAKE image ---
# Claude's response with FAKE image:
# IT0136, B
#
# Reasoning: La domanda riguarda una donna di 19 anni con dolore addominale e diarrea postprandiali, con sospetto di malassorbimento. L'esofagogastroduodenoscopia è stata eseguita per investigare questa condizione.
#
# Nel contesto clinico di:
# - Giovane età (19 anni)
# - Sintomi postprandiali (addominalgia e diarrea)
# - Sospetto di malassorbimento
#
# La diagnosi più probabile è la celiachia (malattia celiaca), che è una delle cause più comuni di malassorbimento in questa fascia d'età.
#
# ...
#
# ## Key Points:
#
# 1. **Study Design**: Case-control study
# 2. **Appropriate Measure**: In case-control studies, we CANNOT calculate relative risk directly because we don't know the true incidence rates in the population. We select cases and controls separately.
# 3. **Correct Measure**: **Odds Ratio (OR)** is the appropriate measure for case-control studies.
#
# ## Standard 2x2 Table Format for Case-Control:
# ```
#                 Disease (Cases)  No Disease (Controls)
# Exposed              a                    b
# Not Exposed          c                    d
# ```
#
# **Odds Ratio formula**: OR = (a × d) / (b × c)
#
# ## Interpreting the Table:
# From the image, the typical format shows:
# - Cases with exposure: 250
# - Cases without exposure: 150
# - Controls with exposure: 100
# - Controls without exposure: 400
#
# Therefore:
# - a = 250 (exposed cases)
# - b = 100 (exposed controls)
# - c = 150 (unexposed cases)
# - d = 400 (unexposed controls)
#
# **Odds Ratio = (250 × 400) / (150 × 100) = 100,000 / 15,000 = 6.67**
#
# ## Evaluating Options:
# - **Options A & B**: Calculate Relative Risk - inappropriate for case-control studies
# - **Option C**: Calculates Attributable Risk - incorrect formula and inappropriate
# - **Option D**: OR = (250×400)/(150×100) ✓ **CORRECT**
# - **Option E**: OR = (150×400)/(250×100) - incorrect cross-product
#
# **IT1100, D**
#
# **Reasoning**: In a case-control study, the Odds Ratio is the correct measure of association since we cannot calculate relative risk directly. The standard formula for OR in a 2×2 table is (a×d)/(b×c), where a=exposed cases, b=exposed controls, c=unexposed cases, d=unexp
#
# ============================================================
# Correct answer: D
# Claude with REAL: D ✓
# Claude with FAKE: PARSE_ERROR ✗
# ============================================================
#
# Successfully loaded image for question IT1113
#
# ============================================================
# Processing question with IMAGE: IT1113
# ============================================================
#
# --- Testing with REAL image ---
# Claude's response with REAL image:
# IT1113, B
#
# Reasoning: La paziente è una donna di 73 anni che presenta dispnea e dolore toracico pleuritico (peggiora durante la respirazione), sintomi classici che devono far sospettare un'embolia polmonare.
#
# Analizzando le immagini:
#
# 1. **Radiografia del torace (sinistra)**: Mostra un'area di ipodiafania (opacità) nel campo polmonare inferiore destro, compatibile con un infarto polmonare o consolidamento. Il cuore appare di dimensioni normali.
#
# 2. **TC torace con contrasto (destra)**: Questa è l'immagine diagnostica chiave. Si evidenzia chiaramente un **difetto di riempimento** (area ipodensa/nera) all'interno dell'arteria polmonare, indicativo di un trombo/embolo che ostruisce il vaso. Questo è il reperto patognomonico dell'embolia polmonare acuta. Inoltre, si può notare un'area di consolidamento/infarto polmonare periferico.
#
# **Esclusione delle altre opzioni:**
# - A) Miocardite acuta: non mostra questi reperti vascolari specifici
# - C) Versamento pericardico: non si vede liquido nel sacco pericardico
# - D) Infarto miocardico acuto: non ci sono alterazioni miocardiche evidenti e il dolore pleuritico è più suggestivo di EP
# - E) Dissezione aortica: l'aorta appare normale, senza flap intimale o doppio lume
#
# La combinazione di sintomi clinici (dispnea, dolore pleuritico) e il difetto di riempimento nell'arteria polmonare alla TC con contrasto confermano inequivocabilmente la diagnosi di embolia polmonare acuta.
#
# --- Testing with FAKE image ---
# Claude's response with FAKE image:
# IT1113, B
#
# Reasoning:
#
# Analisi del caso clinico:
# - Paziente: donna di 73 anni
# - Sintomi: dispnea e dolore toracico pleuritico (peggiora con la respirazione)
# - Imaging: Rx torace e TC torace con mezzo di contrasto
#
# La combinazione di dispnea acuta e dolore toracico di tipo pleuritico in una paziente anziana è altamente suggestiva di embolia polmonare.
#
# Analisi delle opzioni:
#
# A) **Miocardite acuta** - Tipicamente presenta dolore toracico non pleuritico, non è la prima scelta per imaging con TC con mdc
#
# B) **Embolia polmonare acuta** - Questa è la diagnosi più probabile perché:
#    - Il dolore pleuritico è caratteristico dell'EP
#    - La TC torace con mdc è l'esame gold standard per la diagnosi di embolia polmonare (angio-TC)
#    - La combinazione dispnea + dolore pleuritico in paziente anziana è tipica
#    - L'età avanzata è un fattore di rischio per tromboembolismo
#
# C) **Versamento pericardico** - Causerebbe dolore diverso e dispnea, ma la TC con mdc non è l'esame di prima scelta
#
# D) **Infarto miocardico acuto** - Il dolore sarebbe oppressivo/costrittivo, non pleuritico
#
# E) **Dissezione aortica toracica** - Presenterebbe dolore lancinante, "a pugnalata", irradiato posteriormente, non tipicamente pleuritico
#
# La TC torace con mezzo di contrasto (angio-TC) è specificamente indicata per visualizzare i vasi polmonari e identificare difetti di riempimento causati da emboli.
#
# ============================================================
# Correct answer: C
# Claude with REAL: B ✗
# Claude with FAKE: B ✗
# ============================================================
#
# Successfully loaded image for question IT1114
#
# ============================================================
# Processing question with IMAGE: IT1114
# ============================================================
#
# --- Testing with REAL image ---
# Claude's response with REAL image:
# IT1114, E
#
# Reasoning: This is a contrast-enhanced CT angiography (CTA) of the chest with mediastinal window settings in a 45-year-old woman presenting with chest pain and dyspnea.
#
# The key imaging findings are:
#
# 1. **Aortic dissection flap**: There is a clear linear hypodense structure within the aortic lumen, representing an intimal flap that separates the true lumen from the false lumen. This is the pathognomonic finding of aortic dissection.
#
# 2. **Differential contrast opacification**: The two lumens show different degrees of contrast enhancement, with the true lumen typically showing brighter enhancement than the false lumen.
#
# 3. **Location**: The dissection involves the ascending aorta, which would classify this as a Stanford Type A dissection - a surgical emergency.
#
# 4. **Clinical presentation**: Acute chest pain and dyspnea in a middle-aged woman is a classic presentation for aortic dissection.
#
# Let me evaluate the other options:
# - **A) Pulmonary embolism**: Would show filling defects in the pulmonary arteries, not an aortic flap
# - **B) Hemorrhagic thymoma**: Would appear as an anterior mediastinal mass, not an aortic abnormality
# - **C) Multiple pulmonary metastases**: Would show multiple lung nodules, not visible here
# - **D) Superior vena cava syndrome**: Would show SVC obstruction with collateral vessels, not an aortic flap
#
# The imaging clearly demonstrates an aortic dissection flap in the ascending aorta, making aortic dissection the correct diagnosis.
#
# --- Testing with FAKE image ---
# Claude's response with FAKE image:
# IT1114, E
#
# Reasoning:
#
# La paziente è una donna di 45 anni che presenta dolore toracico e dispnea, sintomi classici che richiedono una valutazione urgente per condizioni potenzialmente letali.
#
# Analizzando le opzioni nel contesto clinico:
#
# 1. **Embolia polmonare (A)**: Pur essendo una causa comune di dolore toracico e dispnea, l'angioTC con finestra mediastinica non è la visualizzazione ottimale per identificare emboli polmonari (si usa finestra polmonare). Se fosse embolia, la domanda probabilmente mostrerebbe immagini con finestra polmonare.
#
# 2. **Timoma emorragico (B)**: È una massa mediastinica anteriore, generalmente non si presenta con dolore toracico acuto e dispnea improvvisa.
#
# 3. **Secondarismi polmonari multipli (C)**: Le metastasi polmonari di solito non causano sintomi acuti drammatici come questi, a meno che non ci siano complicanze.
#
# 4. **Sindrome della vena cava superiore (D)**: Si presenta con edema facciale, turgore delle giugulari, e edema degli arti superiori, non primariamente con dolore toracico acuto.
#
# 5. **Dissezione aortica (E)**: Questa è la diagnosi più probabile. La dissezione aortica si presenta classicamente con:
#    - Dolore toracico acuto, spesso lancinante o "a strappo"
#    - Può causare dispnea
#    - Richiede angioTC con mdc per la diagnosi
#    - La finestra mediastinica è ideale per visualizzare l'aorta e identificare il flap intimale caratteristico della dissezione
#    - È un'emergenza medica che richiede diagnosi immediata
#
# La combinazione di sintomi acuti (dolore toracico + dispnea), l'uso specifico di angioTC con finestra me
#
# ============================================================
# Correct answer: A
# Claude with REAL: E ✗
# Claude with FAKE: E ✗
# ============================================================
#
# Successfully loaded image for question IT1118
#
# ============================================================
# Processing question with IMAGE: IT1118
# ============================================================
#
# --- Testing with REAL image ---
# Claude's response with REAL image:
# IT1118, D
#
# Reasoning: L'ematoma subdurale ha caratteristiche di imaging specifiche che lo distinguono da altre lesioni intracraniche:
#
# **Caratteristiche dell'ematoma subdurale:**
# - Si forma nello spazio tra la dura madre e l'aracnoide
# - Non è limitato dalle suture craniche (a differenza dell'epidurale)
# - Si estende lungo la superficie cerebrale seguendo la convessità del cranio
# - Appare come una raccolta a **forma di falce o semiluna** (crescentic shape)
# - Ha un margine interno concavo e un margine esterno convesso che segue la teca cranica
#
# **Analisi delle opzioni:**
#
# A) "Sole radiante" - tipico di lesioni con vascolarizzazione radiale, non pertinente
#
# B) "Lente biconcava" - descrive l'ematoma **epidurale**, che ha entrambi i margini convessi ed è limitato dalle suture
#
# C) "Sale e pepe" - descrive pattern di calcificazioni o lesioni eterogenee
#
# D) **"A falce"** - CORRETTO: descrive perfettamente la forma a semiluna/falce caratteristica dell'ematoma subdurale che si estende lungo la convessità cerebrale
#
# E) "Lente biconvessa" - altro termine per descrivere l'ematoma epidurale (stesso significato di "biconcava")
#
# Nel caso clinico: donna anziana con trauma cranico 3 giorni prima (compatibile con ematoma subdurale, spesso da trauma minore negli anziani per atrofia cerebrale) e l'imaging TC mostra la tipica forma a falce dell'ematoma subdurale.
#
# --- Testing with FAKE image ---
# Claude's response with FAKE image:
# IT1118, D
#
# Reasoning: La domanda riguarda l'aspetto tipico di imaging di un ematoma subdurale alla TC cranio.
#
# Analizziamo le caratteristiche degli ematomi intracranici:
#
# **Ematoma Subdurale:**
# - Si forma nello spazio tra la dura madre e l'aracnoide
# - Non è limitato dalle suture craniche
# - Si distribuisce lungo la superficie cerebrale
# - Assume un aspetto **a falce o a semiluna** (crescent-shaped)
# - Può estendersi su ampie aree della convessità cerebrale
#
# **Ematoma Epidurale:**
# - Si forma tra la teca cranica e la dura madre
# - È limitato dalle suture craniche (dove la dura è aderente)
# - Assume un aspetto **a lente biconvessa o biconcava**
# - Tipicamente più circoscritto
#
# **Altri aspetti:**
# - "A sole radiante": tipico di alcune lesioni ossee o meningiomi
# - "A sale e pepe": caratteristico di paragangliomi o lesioni con calcificazioni/emorragie multiple
#
# Nel caso clinico descritto, una donna di 87 anni con trauma cranico tre giorni prima presenta un ematoma subdurale, che caratteristicamente appare **a falce** (o a semiluna) all'imaging TC, seguendo il profilo della convessità cerebrale.
#
# La risposta corretta è **D) Aspetto "a falce"**.
#
# ============================================================
# Correct answer: D
# Claude with REAL: D ✓
# Claude with FAKE: D ✓
# ============================================================
#
#
# ============================================================
# === SUMMARY ===
# ============================================================
# Total questions processed: 60
# Questions with images: 60
# Questions without images: 0
# Questions skipped: 0
#
# --- Results with REAL images ---
# Correct answers: 51/60
# Accuracy: 85.0%
#
# --- Results with FAKE images ---
# Correct answers: 47/60
# Accuracy: 78.3%
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 364
#     362 # Save results to file
#     363 results_df = pd.DataFrame(results)
# --> 364 results_df.to_csv("revision_11_25/claude_results_real_vs_fake_images_11_25_1.csv", index=False)
#     365 print(f"\nResults saved to claude_results_real_vs_fake_images_11_25_1.csv")
#     367 # Also save skipped questions for reference
#
# File c:\Users\zilef\anaconda3\Lib\site-packages\pandas\core\generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
#    3778     compression=compression,
#    3779     quoting=quoting,
#    3780     columns=columns,
#    3781     index_label=index_label,
#    3782     mode=mode,
#    3783     chunksize=chunksize,
#    3784     quotechar=quotechar,
#    3785     date_format=date_format,
#    3786     doublequote=doublequote,
#    3787     escapechar=escapechar,
#    3788     storage_options=storage_options,
#    3789 )
#
# File c:\Users\zilef\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1186, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1165     created_buffer = False
#    1167 csv_formatter = CSVFormatter(
#    1168     path_or_buf=path_or_buf,
#    1169     lineterminator=lineterminator,
#    (...)
#    1184     formatter=self.fmt,
#    1185 )
# -> 1186 csv_formatter.save()
#    1188 if created_buffer:
#    1189     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\zilef\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:240, in CSVFormatter.save(self)
#     236 """
#     237 Create the writer & save.
#     238 """
#     239 # apply compression and byte/text conversion
# --> 240 with get_handle(
#     241     self.filepath_or_buffer,
#     242     self.mode,
#     243     encoding=self.encoding,
#     244     errors=self.errors,
#     245     compression=self.compression,
#     246     storage_options=self.storage_options,
#     247 ) as handles:
#     248     # Note: self.encoding is irrelevant here
#     249     self.writer = csvlib.writer(
#     250         handles.handle,
#     251         lineterminator=self.lineterminator,
#    (...)
#     256         quotechar=self.quotechar,
#     257     )
#     259     self._save()
#
# File c:\Users\zilef\anaconda3\Lib\site-packages\pandas\io\common.py:737, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     735 # Only for write methods
#     736 if "r" not in mode and is_path:
# --> 737     check_parent_directory(str(handle))
#     739 if compression:
#     740     if compression != "zstd":
#     741         # compression libraries do not like an explicit text-mode
#
# File c:\Users\zilef\anaconda3\Lib\site-packages\pandas\io\common.py:600, in check_parent_directory(path)
#     598 parent = Path(path).parent
#     599 if not parent.is_dir():
# --> 600     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'revision_11_25'

# %%
results_df.to_csv("results/claude_results_real_vs_fake_images_11_25_1.csv", index=False)

# %%
import os

os.getcwd()
# Out:
# 'c:\\Users\\zilef\\OneDrive\\Documents\\eurips2025-mmrl4h-italian-medvqa-visual-grounding\\revision_11_25'
